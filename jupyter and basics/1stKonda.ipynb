# %%
print("hello world")
# Out:
# hello world

# %%
x="*"
for i in range(0,6):
    print("* "*i)
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
print("hello")
print("world",x)
# Out:
# hello
# world *
