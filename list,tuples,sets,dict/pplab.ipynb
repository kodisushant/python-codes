# %%
dance = {1,2,3,4,52,2,12,33}
football = {1,2,3,4,52,89,55,34,78,90}
reading = {78,90,4,6,7,8,9,10}
# print(dance + football) this will not work
# s3 = dance+football+reading this will also not work
s3 = dance.union(football).union(reading)
print(s3)
# s3.add(99)
# s3.add(50)
# print(s3)
onlydance=dance-football-reading
both_dance_football = dance-football
print(both_dance_football)
print(onlydance)
s3.remove(90).add(99)
prints(s3)
# Out:
# {1, 2, 3, 4, 6, 7, 8, 9, 10, 12, 78, 89, 90, 33, 34, 52, 55}
# {33, 12}
# {33, 12}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 15
#      13 print(both_dance_football)
#      14 print(onlydance)
# ---> 15 s3.remove(90).add(99)
#      16 prints(s3)
#
# AttributeError: 'NoneType' object has no attribute 'add'

# %%
l = [20,40,20,40]
l2=list(set(l))
print(l2)ss
# Out:
# [40, 20]

# %%
l = [1,2,3,4,5]
k=3
c = l[len(l)-k:]+l[:len(l)-k]
c
# Out:
# [3, 4, 5, 1, 2]

# %%
l = [1,3,2,3,2,4,5,4,5]
result=[]
for i in l:
    if i not in result:
        result.append(i)
result
# Out:
# [1, 3, 2, 4, 5]

# %%
'''
q)write a program function to swap elements in list at a specified location.
q)to count unique values inside a list.
q)remove duplicates from a list.
q)check if a list contains 3 consecutive common numbers.
q)get unique elements from two lists.
q)find the cumilative sum of elements of a given list.
q)to find the list from a list of lists whose sum of elements is highest
'''

# %%
l = [1,2,3,4,5,6,7]
n1 = int(input("Enter 1st index:"))
n2 = int(input("Enter 2nd index:"))
l[n1],l[n2]=l[n2],l[n1]
l
# Out:
# Enter 1st index: 2
# Enter 2nd index: 6
# [1, 2, 7, 4, 5, 6, 3]

# %%
l = [2,2,3,3,4,4,4,5,5,6,7,8]
l2 = list(set(l))
count = 0
unq=0
for i in range(len(l2)):
    count =0
    for j in range(len(l)):
        if l2[i]==l[j]:
            count = count +1
        if count > 1:
            break
    if count == 1:
        print(l2[i])
        unq+=1
print("no of unique elements =",unq)
# Out:
# 6
# 7
# 8
# no of unique elements = 3

# %%
l = [2,2,3,3,4,4,4,5,5,6,7,8]
l2=list(set(l))
print(l2)
# Out:
# [2, 3, 4, 5, 6, 7, 8]

# %%
l = [2,2,3,3,4,4,4,5,5,6,6,6,7,8]
l2 = list(set(l))
for i in range(len(l)):
    if i >= len(l)-2:
        break
        
    if l[i]==l[i+1] and l[i]==l[i+2]:
        print(l[i],"appered three time at indices",i,i+1,i+2)
    '''
    for j in range(len(l)):
        count = 0
        for k in range(3):
            if l2[i]==l[j+k]:
                count+=1
            else:
                break
        if count == 3:
            print()
    '''
# Out:
# 4 appered three time at indices 4 5 6
# 6 appered three time at indices 9 10 11

# %%
l = [2,2,3,3,4,4,4,5,5,6,6,6,7,8]
l2 = [57,5,7,8,9,1,2,2,3,100,99,81]
ll=set(l)
ll2 = set(l2)
res = ll.union(ll2)- ll.intersection(ll2)
print(list(res))
# Out:
# [1, 99, 4, 100, 6, 9, 81, 57]

# %%
l = [2,2,3,3,4,4,4,5,5,6,6,6,7,8]
print(sum(l))
# Out:
# 65

# %%
l = [[1,2,3,4],[45,5,17,8,9],[30,78,9,1]]
maxx=sum(l[0])
ind = l[0]
for i in l:
    summ=sum(i)
    if summ>maxx:
        maxx = summ
        ind = i
print("the list with highest sum is",ind,"and the sum is",maxx)
# Out:
# the list with highest sum is [30, 78, 9, 1] and the sum is 118

# %%
l = [2,2,3,3,4,4,4,5,5,6,6,6,7,8]
unq = [x for x in l if l.count(x)==1]
print(unq)
# Out:
# [7, 8]
